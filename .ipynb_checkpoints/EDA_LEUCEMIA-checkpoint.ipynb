# %%
import matplotlib.pyplot as plt 
import pandas as pd             
import numpy as np              
import seaborn as sns
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('biased_leukemia_dataset.csv')

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender Country  WBC_Count  RBC_Count  Platelet_Count  \
# 0           1   52    Male   China       2698       5.36          262493
# 1           2   15  Female   China       4857       4.81          277877
# 2           3   72    Male  France       9614       5.17          319600
# 3           4   61    Male  Brazil       6278       5.41          215200
# 4           5   21    Male  Brazil       8342       4.78          309169
#
#    Hemoglobin_Level  Bone_Marrow_Blasts Genetic_Mutation Family_History  \
# 0              12.2                  72              Yes             No
# 1              11.9                  97              Yes             No
# 2              13.4                  94               No            Yes
# 3              11.6                  50               No             No
# 4              14.3                  28               No             No
#
#   Smoking_Status Alcohol_Consumption Radiation_Exposure Infection_History  \
# ...

# %%
df.isna().sum()
# Out:
# Patient_ID              0
# Age                     0
# Gender                  0
# Country                 0
# WBC_Count               0
# RBC_Count               0
# Platelet_Count          0
# Hemoglobin_Level        0
# Bone_Marrow_Blasts      0
# Genetic_Mutation        0
# Family_History          0
# Smoking_Status          0
# Alcohol_Consumption     0
# Radiation_Exposure      0
# Infection_History       0
# BMI                     0
# Chronic_Illness         0
# Immune_Disorders        0
# Ethnicity               0
# Socioeconomic_Status    0
# Urban_Rural             0
# Leukemia_Status         0
# dtype: int64

# %%
df.shape
# Out:
# (143194, 22)

# %%
df.drop_duplicates()
# Out:
#         Patient_ID  Age  Gender    Country  WBC_Count  RBC_Count  \
# 0                1   52    Male      China       2698       5.36
# 1                2   15  Female      China       4857       4.81
# 2                3   72    Male     France       9614       5.17
# 3                4   61    Male     Brazil       6278       5.41
# 4                5   21    Male     Brazil       8342       4.78
# ...            ...  ...     ...        ...        ...        ...
# 143189      143190   11    Male  Argentina       7525       5.30
# 143190      143191   77  Female      China       7258       4.48
# 143191      143192   22  Female        USA       6321       4.94
# 143192      143193   14  Female      India       8039       5.45
# 143193      143194   20    Male     France       7372       5.19
#
#         Platelet_Count  Hemoglobin_Level  Bone_Marrow_Blasts Genetic_Mutation  \
# 0               262493              12.2                  72              Yes
# ...

# %%
df.dtypes
# Out:
# Patient_ID                int64
# Age                       int64
# Gender                      str
# Country                     str
# WBC_Count                 int64
# RBC_Count               float64
# Platelet_Count            int64
# Hemoglobin_Level        float64
# Bone_Marrow_Blasts        int64
# Genetic_Mutation            str
# Family_History              str
# Smoking_Status              str
# Alcohol_Consumption         str
# Radiation_Exposure          str
# Infection_History           str
# BMI                     float64
# Chronic_Illness             str
# Immune_Disorders            str
# Ethnicity                   str
# Socioeconomic_Status        str
# Urban_Rural                 str
# Leukemia_Status             str
# dtype: object

# %%
num_vars = df.select_dtypes(include=['int64','float64']).columns
cat_vars = df.select_dtypes(include=['object','str']).columns

# %%
n_vars = len(num_vars)
fig, axes = plt.subplots(nrows=n_vars, ncols=2, figsize=(15, 5 * n_vars))

# Ensure axes is a 2D array even if there is only 1 variable
if n_vars == 1:
    axes = axes.reshape(1, 2)

for i, col in enumerate(num_vars):
    # --- Plot 1: Distribution (Histogram/Bar style) ---
    sns.histplot(df[col], kde=True,bins=100, color='teal', ax=axes[i, 0])
    axes[i, 0].axvline(df[col].mean(), color='red', linestyle='--', label=f'Mean: {df[col].mean():.2f}')
    axes[i, 0].axvline(df[col].median(), color='orange', linestyle='-', label=f'Median: {df[col].median():.2f}')
    axes[i, 0].set_title(f'Distribution of {col}')
    axes[i, 0].legend()

    # --- Plot 2: Boxplot (Outlier detection) ---
    sns.boxplot(x=df[col], color='teal', ax=axes[i, 1])
    axes[i, 1].set_title(f'Outliers in {col}')

plt.tight_layout()
plt.show()

# %%
n_vars = len(cat_vars)
fig, axes = plt.subplots(nrows=n_vars, ncols=1, figsize=(10, 5 * n_vars))

if n_vars == 1:
    axes = [axes]

for i, col in enumerate(cat_vars):
    sns.countplot(data=df, x=col, ax=axes[i], palette='viridis', 
                  order=df[col].value_counts().index)
    axes[i].set_title(f'Frequency Distribution of {col}')
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_56308/4126125427.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=axes[i], palette='viridis',
# /tmp/ipykernel_56308/4126125427.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45)
# /tmp/ipykernel_56308/4126125427.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, ax=axes[i], palette='viridis',
# /tmp/ipykernel_56308/4126125427.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
df[num_vars].corr()
# Out:
#                     Patient_ID       Age  WBC_Count  RBC_Count  \
# Patient_ID            1.000000  0.001154  -0.001190   0.003927
# Age                   0.001154  1.000000   0.002264  -0.003432
# WBC_Count            -0.001190  0.002264   1.000000   0.000639
# RBC_Count             0.003927 -0.003432   0.000639   1.000000
# Platelet_Count        0.001559  0.002071   0.001954  -0.003046
# Hemoglobin_Level      0.001505 -0.000936  -0.000643   0.000644
# Bone_Marrow_Blasts    0.000304  0.004116  -0.004365  -0.002577
# BMI                  -0.002234 -0.001657  -0.000085  -0.001139
#
#                     Platelet_Count  Hemoglobin_Level  Bone_Marrow_Blasts  \
# Patient_ID                0.001559          0.001505            0.000304
# Age                       0.002071         -0.000936            0.004116
# WBC_Count                 0.001954         -0.000643           -0.004365
# RBC_Count                -0.003046          0.000644           -0.002577
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Gender', hue='Leukemia_Status', palette='magma')
plt.title('Distribución de Leucemia por Género')
plt.xlabel('Género')
plt.ylabel('Cantidad de Pacientes')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

sns.boxplot(data=df, x='Leukemia_Status', y='BMI', ax=axes[0], palette='Set2')
axes[0].set_title('BMI: Positivos vs Negativos')

sns.boxplot(data=df, x='Leukemia_Status', y='Age', ax=axes[1], palette='Set2')
axes[1].set_title('Distribución de Edad por Estado')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_56308/3141403805.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Leukemia_Status', y='BMI', ax=axes[0], palette='Set2')
# /tmp/ipykernel_56308/3141403805.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Leukemia_Status', y='Age', ax=axes[1], palette='Set2')

# %%
blood_counts = df.melt(id_vars=['Leukemia_Status', 'Gender'], 
                       value_vars=['WBC_Count', 'RBC_Count'], 
                       var_name='Cell_Type', value_name='Count')

g = sns.catplot(data=blood_counts, x='Leukemia_Status', y='Count', hue='Gender', col='Cell_Type', kind='box',palette='viridis', height=6, aspect=0.8, sharey=False)

g.set_titles("{col_name}")
g.fig.suptitle('Análisis Hematológico: Estado de Leucemia vs Género', y=1.05)
plt.show()
